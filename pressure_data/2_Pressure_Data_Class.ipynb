# %% [markdown]
# # Loading Pressure Data
#
# Shows an exmaple of loading the Pressure data into the run object using the PressureSensor object.
#
# Author: WaveHello
#
# Date: 07/05/2024

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.io
import os
import sys
from datetime import datetime, timedelta

# %%
# Add the library to the path
sys.path.append(r"C:\ERDC\BarSed")

# Import the library modules

from lib.data_classes.Run import Run
from lib.data_classes.WaveGauge import WaveGauge
from lib.data_classes.WaveMaker import WaveMaker
from lib.data_classes.ADV import ADV

# %% [markdown]
# ## Image of the Pressure sensor ( Figure 4b ) (Look for the circle in the top-middle-left)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Values that are contained in the ADV Struct

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Run number
run_number = "014"

# Run id
run_id = f"RUN{run_number}"

#Name of the run
run_name = r"{}.mat".format(run_id)

# %%
# Set the important paths
barsed_data_path = r"D:\ERDC\BarSed"

# %%
# Name of the folder containing the wave data
WG_data_folder_name = r"WG" 

# Path to where I'm storing the wave data
WG_data_path = os.path.join(barsed_data_path, WG_data_folder_name)

# Path to the first run
wave_file_path = os.path.join(WG_data_path, run_name)

print(f"Wave Gauge file path: {WG_data_path}")
print("Wave Data for mat file path: {}".format(wave_file_path))
# Out:
# Wave Gauge file path: D:\ERDC\BarSed\WG
# Wave Data for mat file path: D:\ERDC\BarSed\WG\RUN014.mat

# %%
# Name of the folder containing the adv data
ADV_data_folder_name = r"ADV"

# Path to where the velocity data is being stored
ADV_data_path = os.path.join(barsed_data_path, ADV_data_folder_name)

# Path to the adv data for the selected run
ADV_file_path = os.path.join(ADV_data_path, run_name)

print(f"{ADV_data_folder_name} file path: {ADV_data_path}")
print("{} Data for mat file path: {}".format(ADV_data_folder_name, ADV_file_path))
# Out:
# ADV file path: D:\ERDC\BarSed\ADV
# ADV Data for mat file path: D:\ERDC\BarSed\ADV\RUN014.mat

# %%
# Make the run object
# test_run =Run(run_id, wave_file_path, ADV_file_path, press_gauge_file_path)

# %%
# Load the mat_dict

# %%
# Test unpacking it

# %%
# Make the function that constructs the object

# %%
# Make the function that stores the data in the pressure gague object
